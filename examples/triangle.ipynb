# %%
import sys
sys.path.append("..")
from contextfree.contextfree import *

# %%
@check_limits
def serp():
    triangle(1)
    with scale(0.5):
        with translate(0, -5.3):
            serp()
        with translate(5, 3):
            serp()
        with translate(-5, 3):
            serp()

init(canvas_size=(300, 300))
with translate(0, 0.3):
    with scale(0.2):
        serp()
        
display_ipython()
