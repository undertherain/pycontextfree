# %%
import sys
from math import sqrt
from contextfree import *

# %%
side = 3 / sqrt(3)

@check_limits
def serp():
    triangle()
    with scale(0.5):
        with translate(0, -1):
            serp()
        with translate(side / 2 , 0.5):
            serp()
        with translate(-side /2, 0.5):
            serp()

init(canvas_size=(300, 300), max_depth=8)
with scale(3):
    with rotate(60):
        serp()
display_ipython()
