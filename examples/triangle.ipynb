# %%
import sys
sys.path.append("..")
import math
from contextfree.contextfree import *

# %%
side = 1
height = math.sqrt(3) * side / 2

@check_limits
def serp():
    triangle(1)
    with scale(0.5):
        with translate(0, - height):
            serp()
        with translate(side, height):
            serp()
        with translate(-side, height):
            serp()

init(canvas_size=(300, 300))
serp()
display_ipython()
