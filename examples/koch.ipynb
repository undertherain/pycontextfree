# %%
import sys
sys.path.append("..")
from math import pi, sqrt
# %load_ext autoreload

# %autoreload 2
import contextfree
from contextfree.contextfree import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
height = sqrt(3) / 2 

@check_limits
def koch():
    triangle()
    with scale(1/3):
        with rotate(math.pi / 3):
            with translate(0, 1):
                koch()
        with rotate(- math.pi / 3):
            with translate(0, 1):
                koch()
        with rotate(math.pi):
            with translate(0, 1):
                koch()
        with translate(0, 1):
            koch()
        with rotate(2 * math.pi/3):
            with translate(0, 1):
                koch()
        with rotate(- 2 * math.pi/3):
            with translate(0, 1):
                koch()


init(canvas_size=(300, 300))
koch()
display_ipython()
