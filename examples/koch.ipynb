# %%
import sys
from math import sqrt
from contextfree import *

# %%
height = sqrt(3) / 2 

@check_limits
def koch():
    triangle()
    with transform(scale=1/3):
        with transform(angle=60):
            with transform(y=1):
                koch()
        with transform(angle=-60):
            with transform(y=1):
                koch()
        with transform(angle=180):
            with transform(y=1):
                koch()
        with transform(y=1):
            koch()
        with transform(angle=120):
            with transform(y=1):
                koch()
        with transform(angle=-120):
            with transform(y=1):
                koch()

init(canvas_size=(300, 300), max_depth=6)
with transform(scale=2):
    koch()
display_ipython()
