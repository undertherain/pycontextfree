# %%
import sys
sys.path.append("..")
from contextfree.contextfree import *

# %%
@check_limits
def branch():
    line(0,1)
    with translate(0,0.9):
        with scale(0.7 + rnd(0.2)):
            with rotate(-0.4 + rnd(0.4)):
                branch()
            with rotate(0.4 + rnd(0.4)):
                branch()


init(canvas_size=(300,300))
with translate(0, -0.5):
    with scale(0.4):
        branch()
        
display_ipython()
