# %%
import sys
from contextfree import *

# %%
@check_limits
def branch():
    line(0,1)
    with transform(y=0.9, scale=0.7 + rnd(0.15), alpha=-0.05):
        with transform(angle=5+prnd(30)):
            branch()
        with transform(angle=-5-prnd(30)):
            branch()


init(canvas_size=(300,300), background_color="#FFFFFF", max_depth=9)
with transform(scale=3):
    branch()
        
display_ipython()
