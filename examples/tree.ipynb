# %%
import sys
sys.path.append("..")
from contextfree import contextfree

# %%
@contextfree.check_limits
def branch():
    contextfree.line(0,1)
    with contextfree.translate(0,0.9):
        with contextfree.scale(0.7+ contextfree.rnd(0.3)):
            with contextfree.rotate(-0.4 + contextfree.rnd(0.5)):
                branch()
            with contextfree.rotate(0.4 + contextfree.rnd(0.5)):
                branch()


contextfree.init(canvas_size=(300,300))
with contextfree.translate(0, -1):
    with contextfree.scale(0.6):
        branch()
        
contextfree.display_ipython()

# %%
contextfree.init()
