# %%
import sys
import math
from contextfree import *

# %%
@check_limits
def branch():
    circle()
    with transform(y=0.5, angle=2, scale_x=0.99):
        branch()
        if coinflip(80):
            with flip_y():
                with scale(0.9):
                    branch()
    
init(canvas_size=(400, 400), max_depth=400, background_color="#ffffff")
with scale(2):
    branch()
display_ipython()
