# %%
import sys
import math
from contextfree.contextfree import *

# %%
side = 1
height = math.sqrt(3) * side / 2

@check_limits
def branch():
    circle(1)
    with translate(0,0.6):
        with rotate(0.04):
            with scale(0.99):
                branch()
        if coinflip(50):
            with flip_y():
                with scale(0.9):
                    branch()
    
init(canvas_size=(400, 400), max_depth=400)
with scale(2):
    branch()
display_ipython()
