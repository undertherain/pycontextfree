# %%
import sys
sys.path.append("..")
import math
from contextfree.contextfree import *

# %%
side = 1
height = math.sqrt(3) * side / 2

@check_limits
def branch():
    circle(1)
    with translate(0,0.6):
        with rotate(0.04):
            with scale(0.99):
                branch()
        if rnd(1)>0.46:
            with flip_y():
                with scale(0.9):
                    branch()
    
init(canvas_size=(400, 400), max_depth=200)
with scale(0.03):
    with translate(0, -20):
        branch()
display_ipython()

# %%
@check_limits
def branch():
    circle(1)
    with translate(0,0.6):
        with rotate(0.04):
            with scale(0.997):
                if coinflip(50):
                    with flip_y():
                        branch()
                else:
                    branch()
            
        if coinflip(50):
            with flip_y():
                with scale(0.9):
                    branch()
    
init(canvas_size=(400, 400), max_depth=500)
with scale(0.012):
    with translate(0, -20):
        branch()
display_ipython()
